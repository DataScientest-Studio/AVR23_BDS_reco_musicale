# %%
import os
from pathlib import Path
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import ipynb

# %%
from ipynb.fs.full.datamanagement import user_filter

# %%
# Read the data
CUR_DIR = os.path.abspath('')

DATA_DIR = Path(CUR_DIR).parent / "data"
FILE_PATH = DATA_DIR/'triplets_metadata_spotify.csv'
df = pd.read_csv(FILE_PATH, index_col = 0)

# %%
df.head()
# Out:
#                                        user  listening_count song_name  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e                1  Stronger
# 1  9fba771d9731561eba47216f6fbfc0023d88641b               19  Stronger
# 2  85952991b8e3ca5803a08b0b2f9c6d71abf9bb5b                1  Stronger
# 3  537340ff896dea11328910013cfe759413e1eeb3                2  Stronger
# 4  8fce200f3912e9608e3b1463cdb9c3529aab5c08                2  Stronger
#
#       release artist_name   duration  artist_familiarity  artist_hotttnesss  \
# 0  Graduation  Kanye West  311.84934            0.877214           1.082503
# 1  Graduation  Kanye West  311.84934            0.877214           1.082503
# 2  Graduation  Kanye West  311.84934            0.877214           1.082503
# 3  Graduation  Kanye West  311.84934            0.877214           1.082503
# 4  Graduation  Kanye West  311.84934            0.877214           1.082503
#
#    year  shs_perf  ...  loudness  mode  speechiness  acousticness  \
# ...

# %%
# Compute the number of listening for each pairs user/songs regardless the release of the song
user_listenings = df.groupby(['user', 'song_name', 'artist_name']).agg({'listening_count' : sum}).reset_index()
user_listenings.head()
# Out:
#                                        user                    song_name  \
# 0  0000175652312d12576d9e6b84f600caa24c4715                  A La Mierda
# 1  0000175652312d12576d9e6b84f600caa24c4715                  Paramilitar
# 2  00001cf0dce3fb22b0df0f3a1d9cd21e38385372          He Doesn't Know Why
# 3  00001cf0dce3fb22b0df0f3a1d9cd21e38385372                  Meadowlarks
# 4  00001cf0dce3fb22b0df0f3a1d9cd21e38385372  Tiger Mountain Peasant Song
#
#    artist_name  listening_count
# 0        Ska-P                1
# 1        Ska-P                1
# 2  Fleet Foxes                1
# 3  Fleet Foxes                2
# 4  Fleet Foxes                1

# %%
# Get the sum of the listering count for a user and the number of songs he have listened
users_summary = user_listenings.groupby('user').agg({'listening_count' : sum, 'song_name' : len}).reset_index()
users_summary.columns = ['user', 'listening_count', 'track_count']

# %%
users_summary.head()
# Out:
#                                        user  listening_count  track_count
# 0  0000175652312d12576d9e6b84f600caa24c4715                2            2
# 1  00001cf0dce3fb22b0df0f3a1d9cd21e38385372                5            4
# 2  0000267bde1b3a70ea75cf2b2d216cb828e3202b                5            4
# 3  00003a4459f33b92906be11abe0e93efc423c0ff                4            2
# 4  00004fb90a86beb8bed1e9e328f5d9b6ee7dc03e                3            3

# %%
users_summary['avg_listening_count_by_song'] = users_summary['listening_count']/users_summary['track_count']

# %%
users_summary.describe()
# Out:
#        listening_count    track_count  avg_listening_count_by_song
# count    849209.000000  849209.000000                849209.000000
# mean         15.878861       5.856914                     3.012249
# std          26.506799       7.613085                     5.256433
# min           1.000000       1.000000                     1.000000
# 25%           3.000000       2.000000                     1.000000
# 50%           7.000000       3.000000                     1.666667
# 75%          18.000000       7.000000                     3.000000
# max        1763.000000     303.000000                  1045.000000

# %%
print('Percent of users who have one listening : %.2f%%' %(sum(users_summary.listening_count == 1)*100/len(users_summary)))
print('Number of users who have less than 5 listening :', sum(users_summary.listening_count > 5))
print('Percent of users who have listened more than 5 different songs : %.2f%%' %(sum(users_summary.track_count > 5)*100/len(users_summary)))
print('Number of users who have listened more than 5 different songs :', sum(users_summary.track_count > 5))
# Out:
# Percent of users who have one listening : 13.17%
# Number of users who have less than 5 listening : 484130
# Percent of users who have listened more than 5 different songs : 31.86%
# Number of users who have listened more than 5 different songs : 270576

# %%
from ipynb.fs.full.datamanagement import user_filter

# %%
ids = user_filter(users_summary, nlist_min = 1, nlist_max = 500, ntracks_min = 5)

# %%
print(len(ids))
# Out:
# 327079
